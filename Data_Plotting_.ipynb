# %% [markdown]
# # Use bar chart for plotting on missing values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
df = pd.read_csv('titanic.csv')
data= df.isnull().sum()
# data2=df.describe() 
# agemean=df['Age'].describe().loc['min']
# print(agemean)

data.plot(kind='bar',color='orangered')
#plt.xlabel("attributes")
#plt.ylabel("Missing values")
# Out:
# <Axes: >

# %% [markdown]
# # Use pie plot for plotting the percentage of survival

# %%
data = df['Survived'].value_counts()
print(data)
plt.pie(data, labels = data.index, autopct ="%1.1f%%", startangle=90, colors=['orange', 'cyan'])
plt.title("Survival Pie Chart")
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# Text(0.5, 1.0, 'Survival Pie Chart')

# %%
sb.histplot(data=df,hue='Survived',multiple='stack',x='Age',kde='True',bins=30)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
data=df.isnull().sum()

data.plot(kind='bar',color='gray')
# Out:
# <Axes: >

# %%
import pandas as pd

sf=pd.read_csv('./titanic.csv')

sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data=sf.columns().to_list()

data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 data=sf.columns(inplace=True).to_list()
#       3 data
#
# TypeError: 'Index' object is not callable
