# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./apple_quality.csv')

df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
df=df.drop(['A_id'],axis=1)

df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 8 columns]

# %%
nan_columns = df.columns[df.isna().any()].tolist()

print(nan_columns)
# Out:
# ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Quality']

# %%
df=df.dropna()

print(df.shape)

df
# Out:
# (4000, 8)
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 8 columns]

# %%
nan_columns = df.columns[df.isna().any()].tolist()

print(nan_columns)
# Out:
# []

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df['Quality']=le.fit_transform(df['Quality'])

df.sample(frac=1)
# Out:
# C:\Users\bhask\AppData\Local\Temp\ipykernel_11912\3432340663.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quality']=le.fit_transform(df['Quality'])
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3609  2.279107 -1.473813   3.693301     2.536904  -2.612737 -3.778314
# 3290 -2.520364  0.233835  -5.671517     1.611891  -2.915728  2.817676
# 2382 -2.105049 -3.789945   1.723247     2.780502   2.251864 -4.805814
# 26   -0.300698 -0.513603   0.921006     1.378172   2.274747  0.745336
# 2592 -0.750567  1.371865  -1.551488     1.319963   1.215877  1.079337
# ...        ...       ...        ...          ...        ...       ...
# 1457  0.529114 -0.165977  -0.476387     1.408195  -1.165197 -0.811165
# 1761 -2.159711 -3.023537  -1.391037    -0.922223   0.840201  1.061032
# 1737  2.169891 -0.685489  -2.563572     1.580902   2.271346 -0.378784
# 3600  0.885404 -1.592329  -3.242057     1.216081  -3.478285  2.560785
# 1224  0.142195 -2.816123  -3.161172     1.187672  -0.352905  0.261585
#
#            Acidity  Quality
# 3609   1.225941103        0
# 3290  -1.021048144        0
# 2382   1.603692081        1
# 26     -2.93402889        1
# 2592  -1.190605373        1
# ...            ...      ...
# 1457   0.020273986        0
# 1761    5.05127048        0
# 1737   2.422487722        0
# 3600  -0.372651142        0
# 1224  -2.589597715        1
#
# [4000 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split 
x=df.drop(['Quality'],axis=1)

y=df['Quality']

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=1)

print('xtrain: ',x_train.shape,'\nxtest:',x_test.shape)
# Out:
# xtrain:  (3200, 7)
# xtest: (800, 7)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


dtc=DecisionTreeClassifier(criterion='entropy')

dtc.fit(x_train,y_train)

pred=dtc.predict(x_test)
asc=accuracy_score(y_test,pred)


print(classification_report(y_test,pred),'\nThe accuracy of the model is:',asc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       409
#            1       0.83      0.87      0.85       391
#
#     accuracy                           0.85       800
#    macro avg       0.85      0.85      0.85       800
# weighted avg       0.85      0.85      0.85       800
#
# The accuracy of the model is: 0.85125
