# %%
import pandas as pd
# import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./apple_quality.csv')

df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
df=df.drop(['A_id'],axis=1)

df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 8 columns]

# %%
nan_columns = df.columns[df.isna().any()].to_list()

print(nan_columns)
# Out:
# ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Quality']

# %%
df=df.dropna()

print(df.shape)

df
# Out:
# (4000, 8)
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 8 columns]

# %%
nan_columns = df.columns[df.isna().any()].tolist()

print(nan_columns)
# Out:
# []

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

df['Quality']=le.fit_transform(df['Quality'])

df.sample(frac=1)
# Out:
# C:\Users\bhask\AppData\Local\Temp\ipykernel_8852\3432340663.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quality']=le.fit_transform(df['Quality'])
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 704  -3.210096  2.248711  -0.990903     0.460363   2.445018 -1.539850
# 127  -3.715530  0.002642   1.683646     0.094039   3.192435 -1.013796
# 33   -0.588796 -1.121987   2.324295     0.311931   5.148739 -3.351988
# 897  -1.701201 -0.825932   1.350336    -0.464459   0.995156  0.867104
# 3452 -0.747773  0.320285  -1.048462     1.431226   0.949918 -2.278244
# ...        ...       ...        ...          ...        ...       ...
# 2399 -1.684840 -1.540055  -0.799607    -0.265964  -1.376356  2.981055
# 1391  0.564010 -0.138908  -3.813118    -0.984473   2.153303  0.948098
# 1969 -2.737079 -2.429581   4.120720     0.617623   0.595397  0.460919
# 3350 -1.759393 -0.609318   0.065757     0.370764   0.397800 -0.935351
# 1952  0.037375  1.389836  -0.244111     1.486669  -2.871368 -1.437053
#
#            Acidity  Quality
# 704   -2.760396429        1
# 127     4.43608798        0
# 33     5.560108693        0
# 897   -3.090406634        1
# 3452  -0.089930972        1
# ...            ...      ...
# 2399    -1.0954011        0
# 1391  -0.030536884        0
# 1969  -0.944009775        1
# 3350   2.635430475        0
# 1952  -0.353434952        1
#
# [4000 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split 
x=df.drop(['Quality'],axis=1)

y=df['Quality']

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=1)

print('xtrain: ',x_train.shape,'\nxtest:',x_test.shape)
# Out:
# xtrain:  (3200, 7)
# xtest: (800, 7)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


dtc=DecisionTreeClassifier(criterion='entropy')

dtc.fit(x_train,y_train)

pred=dtc.predict(x_test)
asc=accuracy_score(y_test,pred)


print(classification_report(y_test,pred),'\nThe accuracy of the model is:',asc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84       409
#            1       0.83      0.86      0.84       391
#
#     accuracy                           0.84       800
#    macro avg       0.85      0.85      0.84       800
# weighted avg       0.85      0.84      0.84       800
#
# The accuracy of the model is: 0.845
